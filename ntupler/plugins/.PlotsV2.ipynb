# %%
import ROOT
ROOT.gStyle.SetOptStat(0)
# Out:
# Welcome to JupyROOT 6.10/05

# %%
#Color Codes
cols1 = 7
cols2 = 1
colb1 = 2
colb2 = 3

# %%
#signal split into two trees, 42k and 35k respectively. This processed file specifically only has the 42k 
#signal from 350k events, so 42k portion from ~188k events, effectively
#background one tree right now, 30k events. Processed from 150k background (Gen-Filtered) events.

signal = ROOT.TFile("~/LTW4/TopTagger/TopTagger/test/TTTT500HTv2.root", "r")
bkgd = ROOT.TFile("~/LTW4/TopTagger/TopTagger/test/TTSLFilt500HTv2.root", "r")

# %%
signal.ls()
# Out:
# TFile**		/afs/cern.ch/user/n/nmangane/LTW4/TopTagger/TopTagger/test/TTTT500HTv2.root
#  TFile*		/afs/cern.ch/user/n/nmangane/LTW4/TopTagger/TopTagger/test/TTTT500HTv2.root
#   KEY: TH1I	h_nTrueRecoTops_full;1	Number of true hadronic tops that are fully in event selection and acceptance
#   KEY: TH1I	h_nTrueRecoTops;1	Number of true hadronic tops in events surviving event selection
#   KEY: TH1I	h_nCandTops_hot;1	Number of tagger candidate (HOT) tops in events surviving event selection
#   KEY: TH1I	h_nCandTops_bdt;1	Number of tagger candidate (BDT) tops in events surviving event selection
#   KEY: TH1I	h_nCandTops_hot1;1	Number of tagger candidate (HOT) tops in events with 1 real hadronic top
#   KEY: TH1I	h_nCandTops_bdt1;1	Number of tagger candidate (BDT) tops in events with 1 real hadronic top
#   KEY: TH1I	h_nCandTops_hot2;1	Number of tagger candidate (HOT) tops in events with 2 real hadronic tops
#   KEY: TH1I	h_nCandTops_bdt2;1	Number of tagger candidate (BDT) tops in events with 2 real hadronic tops
#   KEY: TH1I	h_nCandTops_hot3;1	Number of tagger candidate (HOT) tops in events with 3 real hadronic tops
#   KEY: TH1I	h_nCandTops_bdt3;1	Number of tagger candidate (BDT) tops in events with 3 real hadronic tops
#   KEY: TH1I	h_nCandTops_hot4;1	Number of tagger candidate (HOT) tops in events with 4 real hadronic tops
#   KEY: TH1I	h_nCandTops_bdt4;1	Number of tagger candidate (BDT) tops in events with 4 real hadronic tops
#   KEY: TH1I	h_nCandTops_hot_oth;1	Number of tagger candidate (HOT) tops in events with other category
#   KEY: TH1I	h_nCandTops_bdt_oth;1	Number of tagger candidate (BDT) tops in events with other category
#   KEY: TH1I	h_nCandFullTops_hot1;1	Number of tagger candidate (HOT) tops in events with 1 full-reco hadronic top
#   KEY: TH1I	h_nCandFullTops_bdt1;1	Number of tagger candidate (BDT) tops in events with 1 full-reco hadronic top
#   KEY: TH1I	h_nCandFullTops_hot2;1	Number of tagger candidate (HOT) tops in events with 2 full-reco hadronic tops
#   KEY: TH1I	h_nCandFullTops_bdt2;1	Number of tagger candidate (BDT) tops in events with 2 full-reco hadronic tops
#   KEY: TH1I	h_nCandFullTops_hot3;1	Number of tagger candidate (HOT) tops in events with 3 full-reco hadronic tops
#   KEY: TH1I	h_nCandFullTops_bdt3;1	Number of tagger candidate (BDT) tops in events with 3 full-reco hadronic tops
#   KEY: TH1I	h_nCandFullTops_hot4;1	Number of tagger candidate (HOT) tops in events with 4 full-reco hadronic tops
#   KEY: TH1I	h_nCandFullTops_bdt4;1	Number of tagger candidate (BDT) tops in events with 4 full-reco hadronic tops
#   KEY: TH1I	h_nCandFullTops_hot_0;1	Number of tagger candidate (HOT) tops in events with 0 full-reco hadronic tops
#   KEY: TH1I	h_nCandFullTops_bdt_0;1	Number of tagger candidate (BDT) tops in events with 0 full-reco hadronic tops
#   KEY: TH1F	h_typeIII_hot_;1	Type III (correct) Top Quarks
#   KEY: TH1F	h_typeIIb_hot_;1	Type II (b swapped) Top Quarks
#   KEY: TH1F	h_typeIIw_hot_;1	Type II (q1 or q2 swapped) Top Quarks
#   KEY: TH1F	h_typeIImib_hot_;1	Type II (misidentified b from anywhere non-b) Top Quarks
#   KEY: TH1F	h_typeIImiq_hot_;1	Type II (misidentified q from anywhere non-q) Top Quarks
#   KEY: TH1F	h_typeIt_hot_;1	Type I (3 top-daughters matched, 1 per reco top)
#   KEY: TH1F	h_typeIp_hot_;1	Type I (2 top-daughters matched, 1 per reco top)
#   KEY: TH1F	h_type0xI_hot_;1	Type 0xI (all other tagger candidates)
#   KEY: TH1F	h_eventN1_tIII_hot;1	Highest Disc Cand (Type III)
#   KEY: TH1F	h_eventN1_tII_hot;1	Highest Disc Cand (Type II)
#   KEY: TH1F	h_eventN1_tItp_hot;1	Highest Disc Cand (Type Itp)
#   KEY: TH1F	h_eventN1_t0x1_hot;1	Highest Disc Cand (Type 0x1)
#   KEY: TH1F	h_eventN2_tIII_hot;1	2nd Highest Disc Cand (Type III)
#   KEY: TH1F	h_eventN2_tII_hot;1	2nd Highest Disc Cand (Type II)
#   KEY: TH1F	h_eventN2_tItp_hot;1	2nd Highest Disc Cand (Type Itp)
#   KEY: TH1F	h_eventN2_t0x1_hot;1	2nd Highest Disc Cand (Type 0x1)
#   KEY: TH1F	h_eventN3_tIII_hot;1	3rd Highest Disc Cand (Type III)
#   KEY: TH1F	h_eventN3_tII_hot;1	3rd Highest Disc Cand (Type II)
#   KEY: TH1F	h_eventN3_tItp_hot;1	3rd Highest Disc Cand (Type It / Ip)
#   KEY: TH1F	h_eventN3_t0x1_hot;1	3rd Highest Disc Cand (Type 0 / I)
#   KEY: TH1F	h_typeIII_bdt_;1	Type III (correct) Top Quarks
#   KEY: TH1F	h_typeIIb_bdt_;1	Type II (b swapped) Top Quarks
#   KEY: TH1F	h_typeIIw_bdt_;1	Type II (q1 or q2 swapped) Top Quarks
#   KEY: TH1F	h_typeIImib_bdt_;1	Type II (misidentified b from anywhere non-b) Top Quarks
#   KEY: TH1F	h_typeIImiq_bdt_;1	Type II (misidentified q from anywhere non-q) Top Quarks
#   KEY: TH1F	h_typeIt_bdt_;1	Type I (3 top-daughters matched, 1 per reco top)
#   KEY: TH1F	h_typeIp_bdt_;1	Type I (2 top-daughters matched, 1 per reco top)
#   KEY: TH1F	h_type0xI_bdt_;1	Type 0x1 (all other tagger candidates)
#   KEY: TH1F	h_eventN1_tIII_bdt;1	Highest Disc Cand (Type III)
#   KEY: TH1F	h_eventN1_tII_bdt;1	Highest Disc Cand (Type II)
#   KEY: TH1F	h_eventN1_tItp_bdt;1	Highest Disc Cand (Type It / Ip)
#   KEY: TH1F	h_eventN1_t0x1_bdt;1	Highest Disc Cand (Type 0 / I)
#   KEY: TH1F	h_eventN2_tIII_bdt;1	2nd Highest Disc Cand (Type III)
#   KEY: TH1F	h_eventN2_tII_bdt;1	2nd Highest Disc Cand (Type II)
#   KEY: TH1F	h_eventN2_tItp_bdt;1	2nd Highest Disc Cand (Type It / Ip)
#   KEY: TH1F	h_eventN2_t0x1_bdt;1	2nd Highest Disc Cand (Type 0 / 1)
#   KEY: TH1F	h_eventN3_tIII_bdt;1	3rd Highest Disc Cand (Type III)
#   KEY: TH1F	h_eventN3_tII_bdt;1	3rd Highest Disc Cand (Type II)
#   KEY: TH1F	h_eventN3_tItp_bdt;1	3rd Highest Disc Cand (Type It / Ip)
#   KEY: TH1F	h_eventN3_t0x1_bdt;1	3rd Highest Disc Cand (Type 0x1)
#   KEY: TH1I	h_recoTypes;1	Reconstructible Top Candidates

# %%
h1s = signal.h_nTrueRecoTops_full#Number of true hadronic tops that are fully in event selection and acceptance
h2s = signal.h_nTrueRecoTops
h3s = signal.h_nCandTops_hot
h4s = signal.h_nCandTops_bdt
h5s = signal.h_nCandTops_hot1
h6s = signal.h_nCandTops_bdt1
h7s = signal.h_nCandTops_hot2
h8s = signal.h_nCandTops_bdt2
h9s = signal.h_nCandTops_hot3
h10s = signal.h_nCandTops_bdt3
h11s = signal.h_nCandTops_hot4
h12s = signal.h_nCandTops_bdt4
h13s = signal.h_nCandTops_hot_oth
h14s = signal.h_nCandTops_bdt_oth

# %%
h1b = bkgd.h_nTrueRecoTops_full#Number of true hadronic tops that are fully in event selection and acceptance
h2b = bkgd.h_nTrueRecoTops
h3b = bkgd.h_nCandTops_hot
h4b = bkgd.h_nCandTops_bdt
h5b = bkgd.h_nCandTops_hot1
h6b = bkgd.h_nCandTops_bdt1
h7b = bkgd.h_nCandTops_hot2
h8b = bkgd.h_nCandTops_bdt2
h9b = bkgd.h_nCandTops_hot3
h10b = bkgd.h_nCandTops_bdt3
h11b = bkgd.h_nCandTops_hot4
h12b = bkgd.h_nCandTops_bdt4
h13b = bkgd.h_nCandTops_hot_oth
h14b = bkgd.h_nCandTops_bdt_oth

# %%
c1 = ROOT.TCanvas("c1")
c2 = ROOT.TCanvas("c2")
c3 = ROOT.TCanvas("c3")
c4 = ROOT.TCanvas("c4")
c5 = ROOT.TCanvas("c5")
c6 = ROOT.TCanvas("c6")
c7 = ROOT.TCanvas("c7")
c8 = ROOT.TCanvas("c8")
c9 = ROOT.TCanvas("c9")
c10 = ROOT.TCanvas("c10")
c11 = ROOT.TCanvas("c11")
c12 = ROOT.TCanvas("c12")
c13 = ROOT.TCanvas("c13")
c14 = ROOT.TCanvas("c14")
c15 = ROOT.TCanvas("c15")
c16 = ROOT.TCanvas("c16")
c17 = ROOT.TCanvas("c17")
c18 = ROOT.TCanvas("c18")
c19 = ROOT.TCanvas("c19")
c20 = ROOT.TCanvas("c20")
c21 = ROOT.TCanvas("c21")
c22 = ROOT.TCanvas("c22")
c23 = ROOT.TCanvas("c23")
c24 = ROOT.TCanvas("c24")
c25 = ROOT.TCanvas("c25")
c26 = ROOT.TCanvas("c26")
c27 = ROOT.TCanvas("c27")
c28 = ROOT.TCanvas("c28")
c29 = ROOT.TCanvas("c29")
c30 = ROOT.TCanvas("c30")
c31 = ROOT.TCanvas("c31")
c32 = ROOT.TCanvas("c32")
c33 = ROOT.TCanvas("c33")
c34 = ROOT.TCanvas("c34")

cN1 = ROOT.TCanvas("cN1")
cN2 = ROOT.TCanvas("cN2")
cN3 = ROOT.TCanvas("cN3")

# %%
c1.cd()
h1s.SetFillColor(cols1)
h1b.SetLineColor(colb1)
print("Signal Entries: " + str(h1s.GetEntries()) + "\t\tBackground Entries: " + str(h1b.GetEntries()))
h1s.Draw()
h1b.Draw("Same")
c1.Update()
c1.Draw()
c2.cd()
h2s.SetFillColor(cols1)
h2b.SetLineColor(colb1)
#print("Signal Entries: " + str(h2s.GetEntries()) + "\t\tBackground Entries: " + str(h2b.GetEntries()))
h2b.Draw()
h2s.Draw("Same")
#c2.Update()
c2.Draw()
# Out:
# Signal Entries: 42981.0		Background Entries: 30340.0

# %%
c3.cd()
h3s.SetFillColor(cols1)
h3b.SetLineColor(colb1)
h4s.SetLineColor(cols2)
h4b.SetLineColor(colb2)
h3s.Draw()
h3b.Draw("Same")
#h4s.Draw()
#h4b.Draw("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h3s.GetEntries()) + "\t\tBackground Entries: " + str(h3b.GetEntries()))
c3.Update()
c3.Draw()
# Out:
# Signal Entries: 42981.0		Background Entries: 30340.0

# %%
c4.cd()
h5s.SetFillColor(cols1)
h5b.SetLineColor(colb1)
h6s.SetLineColor(cols2)
h6b.SetLineColor(colb2)
h5b.Draw()
h5s.Draw("Same")
#h6s.Draw()
#h6b.Draw("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h5s.GetEntries()) + "\t\tBackground Entries: " + str(h5b.GetEntries()))
c4.Update()
c4.Draw()
# Out:
# Signal Entries: 3361.0		Background Entries: 28173.0

# %%
c5.cd()
h7s.SetFillColor(cols1)
h7b.SetLineColor(colb1)
h8s.SetLineColor(cols2)
h8b.SetLineColor(colb2)
h7s.Draw()
h7b.Draw("Same")
#h8s.Draw()
#h8b.Draw("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h7s.GetEntries()) + "\t\tBackground Entries: " + str(h7b.GetEntries()))
c5.Update()
c5.Draw()
# Out:
# Signal Entries: 17278.0		Background Entries: 0.0

# %%
c6.cd()
h9s.SetFillColor(cols1)
h9b.SetLineColor(colb1)
h10s.SetLineColor(cols2)
h10b.SetLineColor(colb2)
h9s.Draw()
h9b.Draw("Same")
#h10s.Draw()
#h10b.Draw("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h9s.GetEntries()) + "\t\tBackground Entries: " + str(h9b.GetEntries()))
c6.Update()
c6.Draw()
# Out:
# Signal Entries: 22138.0		Background Entries: 0.0

# %%
c7.cd()
h11s.SetFillColor(cols1)
h11b.SetLineColor(colb1)
h12s.SetLineColor(cols2)
h12b.SetLineColor(colb2)
h11s.Draw()
h11b.Draw("Same")
#h12s.Draw()
#h12b.Draw("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h11s.GetEntries()) + "\t\tBackground Entries: " + str(h11b.GetEntries()))
c7.Update()
c7.Draw()
# Out:
# Signal Entries: 24.0		Background Entries: 0.0

# %%
c8.cd()
h13s.SetFillColor(cols1)
h13b.SetLineColor(colb1)
h14s.SetLineColor(cols2)
h14b.SetLineColor(colb2)
h13b.Draw()
h13s.Draw("Same")
#h14s.Draw()
#h14b.Draw("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h13s.GetEntries()) + "\t\tBackground Entries: " + str(h13b.GetEntries()))
c8.Update()
c8.Draw()
# Out:
# Signal Entries: 180.0		Background Entries: 2167.0

# %%
h15s = signal.h_nCandFullTops_hot_0#;1	Number of tagger candidate (HOT) tops in events with 0 full-reco hadronic tops
h16s = signal.h_nCandFullTops_bdt_0#;1	Number of tagger candidate (BDT) tops in events with 0 full-reco hadronic tops
h17s = signal.h_nCandFullTops_hot1#;1	Number of tagger candidate (HOT) tops in events with 1 full-reco hadronic top
h18s = signal.h_nCandFullTops_bdt1#;1	Number of tagger candidate (BDT) tops in events with 1 full-reco hadronic top
h19s = signal.h_nCandFullTops_hot2#;1	Number of tagger candidate (HOT) tops in events with 2 full-reco hadronic tops
h20s = signal.h_nCandFullTops_bdt2#;1	Number of tagger candidate (BDT) tops in events with 2 full-reco hadronic tops
h21s = signal.h_nCandFullTops_hot3#;1	Number of tagger candidate (HOT) tops in events with 3 full-reco hadronic tops
h22s = signal.h_nCandFullTops_bdt3#;1	Number of tagger candidate (BDT) tops in events with 3 full-reco hadronic tops
h23s = signal.h_nCandFullTops_hot4#;1	Number of tagger candidate (HOT) tops in events with 4 full-reco hadronic tops
h24s = signal.h_nCandFullTops_bdt4#;1	Number of tagger candidate (BDT) tops in events with 4 full-reco hadronic tops

h15b = bkgd.h_nCandFullTops_hot_0#;1	Number of tagger candidate (HOT) tops in events with 0 full-reco hadronic tops
h16b = bkgd.h_nCandFullTops_bdt_0#;1	Number of tagger candidate (BDT) tops in events with 0 full-reco hadronic tops
h17b = bkgd.h_nCandFullTops_hot1#;1	Number of tagger candidate (HOT) tops in events with 1 full-reco hadronic top
h18b = bkgd.h_nCandFullTops_bdt1#;1	Number of tagger candidate (BDT) tops in events with 1 full-reco hadronic top
h19b = bkgd.h_nCandFullTops_hot2#;1	Number of tagger candidate (HOT) tops in events with 2 full-reco hadronic tops
h20b = bkgd.h_nCandFullTops_bdt2#;1	Number of tagger candidate (BDT) tops in events with 2 full-reco hadronic tops
h21b = bkgd.h_nCandFullTops_hot3#;1	Number of tagger candidate (HOT) tops in events with 3 full-reco hadronic tops
h22b = bkgd.h_nCandFullTops_bdt3#;1	Number of tagger candidate (BDT) tops in events with 3 full-reco hadronic tops
h23b = bkgd.h_nCandFullTops_hot4#;1	Number of tagger candidate (HOT) tops in events with 4 full-reco hadronic tops
h24b = bkgd.h_nCandFullTops_bdt4#;1	Number of tagger candidate (BDT) tops in events with 4 full-reco hadronic tops

# %%
c9.cd()
h15s.SetFillColor(cols1)
h15b.SetLineColor(colb1)
h16s.SetLineColor(cols2)
h16b.SetLineColor(colb2)
h15s.Draw()
h15b.Draw("Same")
#h16s.Draw()
#h16b.Draw("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h15s.GetEntries()) + "\t\tBackground Entries: " + str(h15b.GetEntries()))
c9.Update()
c9.Draw()
# Out:
# Signal Entries: 17489.0		Background Entries: 14490.0

# %%
c10.cd()
h17s.SetFillColor(cols1)
h17b.SetLineColor(colb1)
h18s.SetLineColor(cols2)
h18b.SetLineColor(colb2)
h17s.Draw()
h17b.Draw("Same")
#h18s.Draw()
#h18b.Draw("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h17s.GetEntries()) + "\t\tBackground Entries: " + str(h17b.GetEntries()))
c10.Update()
c10.Draw()
# Out:
# Signal Entries: 19815.0		Background Entries: 15850.0

# %%
c11.cd()
h19s.SetFillColor(cols1)
h19b.SetLineColor(colb1)
h20s.SetLineColor(cols2)
h20b.SetLineColor(colb2)
h19s.Draw()
h19b.Draw("Same")
#h20s.Draw()
#h20b.Draw("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h19s.GetEntries()) + "\t\tBackground Entries: " + str(h19b.GetEntries()))
c11.Update()
c11.Draw()
# Out:
# Signal Entries: 5284.0		Background Entries: 0.0

# %%
c12.cd()
h21s.SetFillColor(cols1)
h21b.SetLineColor(colb1)
h22s.SetLineColor(cols2)
h22b.SetLineColor(colb2)
h21s.Draw()
h21b.Draw("Same")
#h22s.DrawNormalized()
#h22b.DrawNormalized("Same")
#print("Teal: TTTT(HOT)\tBlack: TT(HOT)\t)
print("Signal Entries: " + str(h21s.GetEntries()) + "\t\tBackground Entries: " + str(h21b.GetEntries()))
c12.Update()
c12.Draw()
# Out:
# Signal Entries: 393.0		Background Entries: 0.0

# %%
c13.cd()
# Out:
# <ROOT.TCanvas object ("c13") at 0x44440b0>

# %%
h25s = signal.h_typeIII_hot_#;1	Type III (correct) Top Quarks
h26s = signal.h_typeIIb_hot_#;1	Type II (b swapped) Top Quarks
h27s = signal.h_typeIIw_hot_#;1	Type II (q1 or q2 swapped) Top Quarks
h28s = signal.h_typeIImib_hot_#;1	Type II (misidentified b from anywhere non-b) Top Quarks
h29s = signal.h_typeIImiq_hot_#;1	Type II (misidentified q from anywhere non-q) Top Quarks
h30s = signal.h_typeIt_hot_#;1	Type I (3 top-daughters matched, 1 per reco top)
h31s = signal.h_typeIp_hot_#;1	Type I (2 top-daughters matched, 1 per reco top)
h32s = signal.h_type0xI_hot_#;1	Type 0xI (all other tagger candidates)

h25b = bkgd.h_typeIII_hot_#;1	Type III (correct) Top Quarks
h26b = bkgd.h_typeIIb_hot_#;1	Type II (b swapped) Top Quarks
h27b = bkgd.h_typeIIw_hot_#;1	Type II (q1 or q2 swapped) Top Quarks
h28b = bkgd.h_typeIImib_hot_#;1	Type II (misidentified b from anywhere non-b) Top Quarks
h29b = bkgd.h_typeIImiq_hot_#;1	Type II (misidentified q from anywhere non-q) Top Quarks
h30b = bkgd.h_typeIt_hot_#;1	Type I (3 top-daughters matched, 1 per reco top)
h31b = bkgd.h_typeIp_hot_#;1	Type I (2 top-daughters matched, 1 per reco top)
h32b = bkgd.h_type0xI_hot_#;1	Type 0xI (all other tagger candidates)

# %%
c14.cd()
h25s.SetFillColor(cols1)
h25b.SetLineColor(colb1)
h25b.SetMarkerStyle(5)
h25s.DrawNormalized()
h25b.DrawNormalized("Same")
print("Signal Entries: " + str(h25s.GetEntries()) + "\t\tBackground Entries: " + str(h25b.GetEntries()))
c14.Update()
c14.Draw()
# Out:
# Signal Entries: 14137.0		Background Entries: 9175.0

# %%
c15.cd()
h26s.SetFillColor(cols1)
h26b.SetLineColor(colb1)
h26b.SetMarkerStyle(5)
h26s.DrawNormalized()
#h26b.Draw("Same")
print("Signal Entries: " + str(h26s.GetEntries()) + "\t\tBackground Entries: " + str(h26b.GetEntries()))
c15.Update()
c15.Draw()
# Out:
# Signal Entries: 2516.0		Background Entries: 0.0

# %%
c16.cd()
h27s.SetFillColor(cols1)
h27b.SetLineColor(colb1)
h27b.SetMarkerStyle(5)
h27s.DrawNormalized()
#h27b.DrawNormalized("Same")
print("Signal Entries: " + str(h27s.GetEntries()) + "\t\tBackground Entries: " + str(h27b.GetEntries()))
c16.Update()
c16.Draw()
# Out:
# Signal Entries: 5682.0		Background Entries: 0.0

# %%
c17.cd()
h28s.SetFillColor(cols1)
h28b.SetLineColor(colb1)
h28b.SetMarkerStyle(5)
h28s.DrawNormalized()
h28b.DrawNormalized("Same")
print("Signal Entries: " + str(h28s.GetEntries()) + "\t\tBackground Entries: " + str(h28b.GetEntries()))
c17.Update()
c17.Draw()
# Out:
# Signal Entries: 8468.0		Background Entries: 3526.0

# %%
c18.cd()
h29s.SetFillColor(cols1)
h29b.SetLineColor(colb1)
h29b.SetMarkerStyle(5)
h29b.DrawNormalized()
h29s.DrawNormalized("Same")
h29b.DrawNormalized("Same")
print("Signal Entries: " + str(h29s.GetEntries()) + "\t\tBackground Entries: " + str(h29b.GetEntries()))
c18.Update()
c18.Draw()
# Out:
# Signal Entries: 13921.0		Background Entries: 6358.0

# %%
c19.cd()
h30s.SetFillColor(cols1)
h30b.SetLineColor(colb1)
h30b.SetMarkerStyle(5)
h30s.DrawNormalized()
#h30b.DrawNormalized("Same")
print("Signal Entries: " + str(h30s.GetEntries()) + "\t\tBackground Entries: " + str(h30b.GetEntries()))
c19.Update()
c19.Draw()
# Out:
# Signal Entries: 1051.0		Background Entries: 0.0

# %%
c20.cd()
h31s.SetFillColor(cols1)
h31b.SetLineColor(colb1)
h31b.SetMarkerStyle(5)
h31s.DrawNormalized()
#h31b.DrawNormalized("Same")
print("Signal Entries: " + str(h31s.GetEntries()) + "\t\tBackground Entries: " + str(h31b.GetEntries()))
c20.Update()
c20.Draw()
# Out:
# Signal Entries: 8591.0		Background Entries: 0.0

# %%
c21.cd()
h32s.SetFillColor(cols1)
h32b.SetLineColor(colb1)
h32b.SetMarkerStyle(5)
h32s.DrawNormalized()
h32b.DrawNormalized("Same")
print("Signal Entries: " + str(h32s.GetEntries()) + "\t\tBackground Entries: " + str(h32b.GetEntries()))
c21.Update()
c21.Draw()
# Out:
# Signal Entries: 22984.0		Background Entries: 29999.0

# %%
h33s = signal.h_eventN1_tIII_hot#;1	Highest Disc Cand (Type III) 
h34s = signal.h_eventN1_tII_hot#;1	Highest Disc Cand (Type II) 
h35s = signal.h_eventN1_tItp_hot#;1	Highest Disc Cand (Type Itp) 
h36s = signal.h_eventN1_t0x1_hot#;1	Highest Disc Cand (Type 0x1) 

h33b = bkgd.h_eventN1_tIII_hot#;1	Highest Disc Cand (Type III) 
h34b = bkgd.h_eventN1_tII_hot#;1	Highest Disc Cand (Type II) 
h35b = bkgd.h_eventN1_tItp_hot#;1	Highest Disc Cand (Type Itp) 
h36b = bkgd.h_eventN1_t0x1_hot#;1	Highest Disc Cand (Type 0x1)

# %%
c22.cd()
h33s.SetFillColor(cols1)
h33b.SetLineColor(colb1)
h33b.SetMarkerStyle(5)
h33s.DrawNormalized()
h33b.DrawNormalized("Same")
print("Signal Entries: " + str(h33s.GetEntries()) + "\t\tBackground Entries: " + str(h33b.GetEntries()))
c22.Update()
c22.Draw()
# Out:
# Signal Entries: 10510.0		Background Entries: 8708.0

# %%
c23.cd()
h34s.SetFillColor(cols1)
h34b.SetLineColor(colb1)
h34b.SetMarkerStyle(5)
h34s.DrawNormalized()
h34b.DrawNormalized("Same")
print("Signal Entries: " + str(h34s.GetEntries()) + "\t\tBackground Entries: " + str(h34b.GetEntries()))
c23.Update()
c23.Draw()
# Out:
# Signal Entries: 17281.0		Background Entries: 8001.0

# %%
c24.cd()
h35s.SetFillColor(cols1)
h35b.SetLineColor(colb1)
h35b.SetMarkerStyle(5)
h35s.DrawNormalized()
#h35b.DrawNormalized("Same")
print("Signal Entries: " + str(h35s.GetEntries()) + "\t\tBackground Entries: " + str(h35b.GetEntries()))
c24.Update()
c24.Draw()
# Out:
# Signal Entries: 4927.0		Background Entries: 0.0

# %%
c25.cd()
h36s.SetFillColor(cols1)
h36b.SetLineColor(colb1)
h36b.SetMarkerStyle(5)
h36s.DrawNormalized()
h36b.DrawNormalized("Same")
print("Signal Entries: " + str(h36s.GetEntries()) + "\t\tBackground Entries: " + str(h36b.GetEntries()))
c25.Update()
c25.Draw()
# Out:
# Signal Entries: 9257.0		Background Entries: 13084.0

# %%
N1Ssum = h33s + h34s + h35s + h36s
N1Bsum = h33b + h34b + h35b + h36b
N1Ssum.SetTitle("Highest Disc Cand (All)")
N1Ssum.SetFillColorAlpha(cols1, 0.25)
N1Bsum.SetFillColorAlpha(3, 0.25)
cN1.cd()
print("Signal Entries: " + str(N1Ssum.GetEntries()) + "\t\tBackground Entries: " + str(N1Bsum.GetEntries()))
N1Ssum.DrawNormalized()
N1Bsum.DrawNormalized("Same")
cN1.Update()
cN1.Draw()
# Out:
# Signal Entries: 41975.0		Background Entries: 29793.0

# %%
h37s = signal.h_eventN2_tIII_hot#;1	Highest Disc Cand (Type III) 
h38s = signal.h_eventN2_tII_hot#;1	Highest Disc Cand (Type II) 
h39s = signal.h_eventN2_tItp_hot#;1	Highest Disc Cand (Type Itp) 
h40s = signal.h_eventN2_t0x1_hot#;1	Highest Disc Cand (Type 0x1) 

h37b = bkgd.h_eventN2_tIII_hot#;1	Highest Disc Cand (Type III) 
h38b = bkgd.h_eventN2_tII_hot#;1	Highest Disc Cand (Type II) 
h39b = bkgd.h_eventN2_tItp_hot#;1	Highest Disc Cand (Type Itp) 
h40b = bkgd.h_eventN2_t0x1_hot#;1	Highest Disc Cand (Type 0x1)

# %%
c26.cd()
h37s.SetFillColor(cols1)
h37b.SetLineColor(colb1)
h37b.SetMarkerStyle(5)
h37s.DrawNormalized()
h37b.DrawNormalized("Same")
print("Signal Entries: " + str(h37s.GetEntries()) + "\t\tBackground Entries: " + str(h37b.GetEntries()))
c26.Update()
c26.Draw()
# Out:
# Signal Entries: 3277.0		Background Entries: 460.0

# %%
c27.cd()
h38s.SetFillColorAlpha(cols1, 0.4)
h38b.SetFillColorAlpha(colb1, 0.25)
h38b.SetMarkerStyle(5)
h38s.DrawNormalized()
h38b.DrawNormalized("Same")
print("Signal Entries: " + str(h38s.GetEntries()) + "\t\tBackground Entries: " + str(h38b.GetEntries()))
c27.Update()
c27.Draw()
# Out:
# Signal Entries: 11367.0		Background Entries: 1822.0

# %%
c28.cd()
h39s.SetFillColor(cols1)
h39b.SetLineColor(colb1)
h39b.SetMarkerStyle(5)
h39s.DrawNormalized()
#h39b.DrawNormalized("Same")
print("Signal Entries: " + str(h39s.GetEntries()) + "\t\tBackground Entries: " + str(h39b.GetEntries()))
c28.Update()
c28.Draw()
# Out:
# Signal Entries: 3818.0		Background Entries: 0.0

# %%
c29.cd()
h40s.SetFillColor(cols1)
h40b.SetLineColor(colb1)
h40b.SetMarkerStyle(5)
h40b.DrawNormalized()
h40s.DrawNormalized("Same")
h40b.DrawNormalized("Same")
print("Signal Entries: " + str(h40s.GetEntries()) + "\t\tBackground Entries: " + str(h40b.GetEntries()))
c29.Update()
c29.Draw()
# Out:
# Signal Entries: 10303.0		Background Entries: 15738.0

# %%
N2Ssum = h37s + h38s + h39s + h40s
N2Bsum = h37b + h38b + h39b + h40b
N2Ssum.SetTitle("2nd Highest Disc Cand (All)")
N2Ssum.SetLineColor(0)
N2Bsum.SetLineColor(0)
N2Ssum.SetFillColorAlpha(cols1, 0.4)
N2Bsum.SetFillColorAlpha(colb1, 0.4)
cN2.cd()
print("Signal Entries: " + str(N2Ssum.GetEntries()) + "\t\tBackground Entries: " + str(N2Bsum.GetEntries()))
N2Ssum.DrawNormalized()
N2Bsum.DrawNormalized("Same")
cN2.Update()
cN2.Draw()
# Out:
# Signal Entries: 28765.0		Background Entries: 18020.0

# %%
SP = ROOT.TH1F("SP", "Separation Power (2nd Highest Discriminant); Discriminant; Power", N2Ssum.GetNbinsX(), 0, 1.0)
cSP = ROOT.TCanvas("cSP")

# %%
grid = xrange(N2Ssum.GetNbinsX())
SInt = [N2Ssum.Integral(x, -1)/N2Ssum.GetEntries() for x in grid]
BInt = [N2Bsum.Integral(x, -1)/N2Bsum.GetEntries() for x in grid]
SepPow = [(SInt[x] - BInt[x])/SInt[x] for x in grid]
print(SepPow)
print(N2Ssum.GetNbinsX())
SP.Reset()

cSP.cd()
SP.Draw()
cSP.Update()
cSP.Draw()
# Out:
# [0.0, 0.0, 0.07582145891691773, 0.11818977865265007, 0.1611714539763188, 0.197925110926638, 0.2340958446086583, 0.27055555668808934, 0.30624055330392574, 0.3394645056685831, 0.3695209567707252, 0.40017333422845003, 0.4336482727726974, 0.4680859133554809, 0.4985563053770701, 0.5412479424759595, 0.5804951910862095, 0.6184959903345669, 0.6687233689042261, 0.7377731770018119]
# 20

# %%
h41s = signal.h_eventN3_tIII_hot#;1	Highest Disc Cand (Type III) 
h42s = signal.h_eventN3_tII_hot#;1	Highest Disc Cand (Type II) 
h43s = signal.h_eventN3_tItp_hot#;1	Highest Disc Cand (Type Itp) 
h44s = signal.h_eventN3_t0x1_hot#;1	Highest Disc Cand (Type 0x1) 

h41b = bkgd.h_eventN3_tIII_hot#;1	Highest Disc Cand (Type III) 
h42b = bkgd.h_eventN3_tII_hot#;1	Highest Disc Cand (Type II) 
h43b = bkgd.h_eventN3_tItp_hot#;1	Highest Disc Cand (Type Itp) 
h44b = bkgd.h_eventN3_t0x1_hot#;1	Highest Disc Cand (Type 0x1)

# %%
#N3sum = H41.s

# %%
c30.cd()
h41s.SetFillColor(cols1)
h41b.SetLineColor(colb1)
h41b.SetMarkerStyle(5)
h41b.DrawNormalized()
h41s.DrawNormalized("Same")
print("Signal Entries: " + str(h41s.GetEntries()) + "\t\tBackground Entries: " + str(h41b.GetEntries()))
c30.Update()
c30.Draw()
# Out:
# Signal Entries: 346.0		Background Entries: 7.0

# %%
c31.cd()
h42s.SetFillColor(cols1)
h42b.SetLineColor(colb1)
h42b.SetMarkerStyle(5)
h42b.DrawNormalized()
h42s.DrawNormalized("Same")
h42b.DrawNormalized("Same")
print("Signal Entries: " + str(h42s.GetEntries()) + "\t\tBackground Entries: " + str(h42b.GetEntries()))
c31.Update()
c31.Draw()
# Out:
# Signal Entries: 1887.0		Background Entries: 61.0

# %%
c32.cd()
h43s.SetFillColor(cols1)
h43b.SetLineColor(colb1)
h43b.SetMarkerStyle(5)
h43s.DrawNormalized()
#h43b.DrawNormalized("Same")
print("Signal Entries: " + str(h43s.GetEntries()) + "\t\tBackground Entries: " + str(h43b.GetEntries()))
c32.Update()
c32.Draw()
# Out:
# Signal Entries: 868.0		Background Entries: 0.0

# %%
c33.cd()
h44s.SetFillColor(cols1)
h44b.SetLineColor(colb1)
h44b.SetMarkerStyle(5)
h44b.DrawNormalized()
h44s.DrawNormalized("Same")
h44b.DrawNormalized("Same")
print("Signal Entries: " + str(h44s.GetEntries()) + "\t\tBackground Entries: " + str(h44b.GetEntries()))
c33.Update()
c33.Draw()
# Out:
# Signal Entries: 3196.0		Background Entries: 1160.0

# %%
N3Ssum = h41s + h42s + h43s + h44s
N3Bsum = h41b + h42b + h43b + h44b
N3Ssum.SetTitle("3rd Highest Disc Cand (All)")
cN3.cd()
print("Signal Entries: " + str(N3Ssum.GetEntries()) + "\t\tBackground Entries: " + str(N3Bsum.GetEntries()))
N3Bsum.DrawNormalized()
N3Ssum.DrawNormalized("Same")
N3Bsum.DrawNormalized("Same")
cN3.Update()
cN3.Draw()
# Out:
# Signal Entries: 6297.0		Background Entries: 1228.0
